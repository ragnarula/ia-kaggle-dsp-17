# %%
import sys
sys.path.append("../")

# %%
import config
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
data_dir = '../data/small'
labels = '../data/stage1_labels.csv'
labels_df = pd.read_csv(labels)
stream = config.unet_roi(data_dir, labels_df)

# %%
for item in stream:
    dataset, idd, image = item
    c, h, w = image.shape
    if image is not None:
        plt.imshow(image.reshape(h, w), cmap='bone')
        plt.show()
    else:
        print("no ROIS")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8ca3003f4a6f> in <module>()
#       4     if image is not None:
#       5         plt.imshow(image.reshape(h, w), cmap='bone')
# ----> 6         plt.show()
#       7     else:
#       8         print("no ROIS")
#
# /Users/rag/code/scratch/ia-kaggle_dsb_17/.env/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# /Users/rag/code/scratch/ia-kaggle_dsb_17/.env/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ...
